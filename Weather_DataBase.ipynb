# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in /Users/evafuentes/opt/anaconda3/lib/python3.7/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /Users/evafuentes/opt/anaconda3/lib/python3.7/site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
from citipy import citipy
#The citipy module finds the nearest city to
#the latitude and longitude pair with a
#population of 500 or more.

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 654

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=012541f2b50b057a69bcf2857299396d

# %%
#STEP 1
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1



# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        try:
            city_rain = city_weather["rain"]["3h"]
        except KeyError:
            city_rain = 0
        try:
            city_snow = city_weather["snow"]["3h"]
        except KeyError:
            city_snow = 0
            
            
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                            "Lat": city_lat,
                            "Lng": city_lng,
                            "Max Temp": city_max_temp,
                            "Humidity": city_humidity,
                            "Cloudiness": city_clouds,
                            "Wind Speed": city_wind,
                            "Country": city_country,
                            "Current Description": city_description,
                            "Rain inches (last 3 hrs)": city_rain,
                            "Snow inches (last 3 hrs)": city_snow,
                            "Date": city_date})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

    # Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 1 | aguimes
# Processing Record 3 of Set 1 | itarema
# Processing Record 4 of Set 1 | kodiak
# Processing Record 5 of Set 1 | clyde river
# Processing Record 6 of Set 1 | mombasa
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | hobart
# Processing Record 9 of Set 1 | arraial do cabo
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | sioux lookout
# Processing Record 12 of Set 1 | husavik
# Processing Record 13 of Set 1 | bluff
# Processing Record 14 of Set 1 | vejprnice
# Processing Record 15 of Set 1 | macroom
# Processing Record 16 of Set 1 | hilo
# Processing Record 17 of Set 1 | pochutla
# Processing Record 18 of Set 1 | shostka
# Processing Record 19 of Set 1 | bokoro
# Processing Record 20 of Set 1 | barrow
# Processing Record 21 of Set 1 | roma
# Processing Record 22 of Set 1 | tongzi
# Processing Record 23 of Set 1 | san patricio
# Processing Record 24 of Set 1 | norman wells
# Processing Record 25 of Set 1 | tasiilaq
# Processing Record 26 of Set 1 | saint-philippe
# Processing Record 27 of Set 1 | yellowknife
# Processing Record 28 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 1 | hithadhoo
# Processing Record 30 of Set 1 | mishan
# Processing Record 31 of Set 1 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 32 of Set 1 | isla mujeres
# Processing Record 33 of Set 1 | macaboboni
# City not found. Skipping...
# Processing Record 34 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 1 | georgetown
# Processing Record 36 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 1 | busselton
# Processing Record 38 of Set 1 | lebu
# Processing Record 39 of Set 1 | taltal
# Processing Record 40 of Set 1 | tiksi
# Processing Record 41 of Set 1 | gat
# Processing Record 42 of Set 1 | ugoofaaru
# Processing Record 43 of Set 1 | bangkalan
# Processing Record 44 of Set 1 | ocampo
# Processing Record 45 of Set 1 | avarua
# Processing Record 46 of Set 1 | new norfolk
# Processing Record 47 of Set 1 | victor harbor
# Processing Record 48 of Set 1 | igrim
# Processing Record 49 of Set 1 | thompson
# Processing Record 50 of Set 1 | tolaga bay
# Processing Record 1 of Set 2 | kruisfontein
# Processing Record 2 of Set 2 | kurilsk
# Processing Record 3 of Set 2 | dingle
# Processing Record 4 of Set 2 | aklavik
# Processing Record 5 of Set 2 | san carlos de bariloche
# Processing Record 6 of Set 2 | qaanaaq
# Processing Record 7 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 2 | davidson
# Processing Record 9 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 2 | bengkulu
# Processing Record 11 of Set 2 | saint-denis
# Processing Record 12 of Set 2 | cidreira
# Processing Record 13 of Set 2 | atuona
# Processing Record 14 of Set 2 | cervo
# Processing Record 15 of Set 2 | oranjemund
# Processing Record 16 of Set 2 | iqaluit
# Processing Record 17 of Set 2 | albany
# Processing Record 18 of Set 2 | codrington
# Processing Record 19 of Set 2 | cherskiy
# Processing Record 20 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 2 | takhli
# Processing Record 22 of Set 2 | erdenet
# Processing Record 23 of Set 2 | talara
# Processing Record 24 of Set 2 | yumen
# Processing Record 25 of Set 2 | lang son
# Processing Record 26 of Set 2 | ostrovnoy
# Processing Record 27 of Set 2 | mataura
# Processing Record 28 of Set 2 | andenes
# Processing Record 29 of Set 2 | riaba
# City not found. Skipping...
# Processing Record 30 of Set 2 | kaeo
# Processing Record 31 of Set 2 | asau
# Processing Record 32 of Set 2 | cabra
# Processing Record 33 of Set 2 | hamilton
# Processing Record 34 of Set 2 | comodoro rivadavia
# Processing Record 35 of Set 2 | tynda
# Processing Record 36 of Set 2 | pangnirtung
# Processing Record 37 of Set 2 | port alfred
# Processing Record 38 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 2 | san carlos
# Processing Record 40 of Set 2 | nikolskoye
# Processing Record 41 of Set 2 | vaini
# Processing Record 42 of Set 2 | lagoa
# Processing Record 43 of Set 2 | chokurdakh
# Processing Record 44 of Set 2 | lorengau
# Processing Record 45 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 2 | tamandare
# Processing Record 47 of Set 2 | itoman
# Processing Record 48 of Set 2 | bambous virieux
# Processing Record 49 of Set 2 | oudtshoorn
# Processing Record 50 of Set 2 | bocaranga
# City not found. Skipping...
# Processing Record 1 of Set 3 | dikson
# Processing Record 2 of Set 3 | sept-iles
# Processing Record 3 of Set 3 | punta arenas
# Processing Record 4 of Set 3 | tuatapere
# Processing Record 5 of Set 3 | coihaique
# Processing Record 6 of Set 3 | victoria
# Processing Record 7 of Set 3 | east london
# Processing Record 8 of Set 3 | touros
# Processing Record 9 of Set 3 | carahue
# Processing Record 10 of Set 3 | springfield
# Processing Record 11 of Set 3 | mayo
# Processing Record 12 of Set 3 | hermanus
# Processing Record 13 of Set 3 | ribeira grande
# Processing Record 14 of Set 3 | ponta do sol
# Processing Record 15 of Set 3 | cookeville
# Processing Record 16 of Set 3 | bubaque
# Processing Record 17 of Set 3 | longyearbyen
# Processing Record 18 of Set 3 | port elizabeth
# Processing Record 19 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 20 of Set 3 | tapaua
# City not found. Skipping...
# Processing Record 21 of Set 3 | jamestown
# Processing Record 22 of Set 3 | torbay
# Processing Record 23 of Set 3 | kapaa
# Processing Record 24 of Set 3 | zhigansk
# Processing Record 25 of Set 3 | mahibadhoo
# Processing Record 26 of Set 3 | bereda
# Processing Record 27 of Set 3 | tazovskiy
# Processing Record 28 of Set 3 | cape town
# Processing Record 29 of Set 3 | toktogul
# Processing Record 30 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 31 of Set 3 | jumla
# Processing Record 32 of Set 3 | merauke
# Processing Record 33 of Set 3 | namatanai
# Processing Record 34 of Set 3 | tessalit
# Processing Record 35 of Set 3 | guerrero negro
# Processing Record 36 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 3 | meulaboh
# Processing Record 38 of Set 3 | surt
# Processing Record 39 of Set 3 | salalah
# Processing Record 40 of Set 3 | ingham
# Processing Record 41 of Set 3 | mehamn
# Processing Record 42 of Set 3 | malwan
# City not found. Skipping...
# Processing Record 43 of Set 3 | kemin
# Processing Record 44 of Set 3 | esperance
# Processing Record 45 of Set 3 | bethel
# Processing Record 46 of Set 3 | hovd
# Processing Record 47 of Set 3 | sitka
# Processing Record 48 of Set 3 | leningradskiy
# Processing Record 49 of Set 3 | butaritari
# Processing Record 50 of Set 3 | polignano a mare
# Processing Record 1 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 4 | chicama
# Processing Record 3 of Set 4 | brigantine
# Processing Record 4 of Set 4 | souillac
# Processing Record 5 of Set 4 | malpe
# Processing Record 6 of Set 4 | cheuskiny
# City not found. Skipping...
# Processing Record 7 of Set 4 | flin flon
# Processing Record 8 of Set 4 | faanui
# Processing Record 9 of Set 4 | totma
# Processing Record 10 of Set 4 | igarka
# Processing Record 11 of Set 4 | azogues
# Processing Record 12 of Set 4 | castro
# Processing Record 13 of Set 4 | walvis bay
# Processing Record 14 of Set 4 | yerbogachen
# Processing Record 15 of Set 4 | ambodifototra
# City not found. Skipping...
# Processing Record 16 of Set 4 | komsomolskiy
# Processing Record 17 of Set 4 | kupang
# Processing Record 18 of Set 4 | bundaberg
# Processing Record 19 of Set 4 | koumac
# Processing Record 20 of Set 4 | asyut
# Processing Record 21 of Set 4 | margate
# Processing Record 22 of Set 4 | sindand
# City not found. Skipping...
# Processing Record 23 of Set 4 | khatanga
# Processing Record 24 of Set 4 | shenjiamen
# Processing Record 25 of Set 4 | baykit
# Processing Record 26 of Set 4 | igbo ora
# Processing Record 27 of Set 4 | burica
# City not found. Skipping...
# Processing Record 28 of Set 4 | saskylakh
# Processing Record 29 of Set 4 | bristol
# Processing Record 30 of Set 4 | bosaso
# Processing Record 31 of Set 4 | severo-kurilsk
# Processing Record 32 of Set 4 | lafiagi
# Processing Record 33 of Set 4 | bitung
# Processing Record 34 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 4 | dalby
# Processing Record 36 of Set 4 | bay roberts
# Processing Record 37 of Set 4 | dangriga
# Processing Record 38 of Set 4 | san quintin
# Processing Record 39 of Set 4 | chuy
# Processing Record 40 of Set 4 | plainview
# Processing Record 41 of Set 4 | cuamba
# Processing Record 42 of Set 4 | nakhon phanom
# Processing Record 43 of Set 4 | panaba
# Processing Record 44 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 4 | mangrol
# Processing Record 46 of Set 4 | machachi
# Processing Record 47 of Set 4 | bredasdorp
# Processing Record 48 of Set 4 | tilichiki
# Processing Record 49 of Set 4 | erzurum
# Processing Record 50 of Set 4 | pundaguitan
# Processing Record 1 of Set 5 | rudbar
# Processing Record 2 of Set 5 | caceres
# Processing Record 3 of Set 5 | hammerfest
# Processing Record 4 of Set 5 | nanortalik
# Processing Record 5 of Set 5 | broken hill
# Processing Record 6 of Set 5 | vanimo
# Processing Record 7 of Set 5 | alofi
# Processing Record 8 of Set 5 | le port
# Processing Record 9 of Set 5 | umm kaddadah
# Processing Record 10 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 5 | starychi
# Processing Record 12 of Set 5 | klaksvik
# Processing Record 13 of Set 5 | hay river
# Processing Record 14 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 5 | tasbuget
# City not found. Skipping...
# Processing Record 16 of Set 5 | usinsk
# Processing Record 17 of Set 5 | omsukchan
# Processing Record 18 of Set 5 | kudinovo
# Processing Record 19 of Set 5 | olafsvik
# Processing Record 20 of Set 5 | provideniya
# Processing Record 21 of Set 5 | hellvik
# Processing Record 22 of Set 5 | katsuura
# Processing Record 23 of Set 5 | puerto baquerizo moreno
# Processing Record 24 of Set 5 | kirkwall
# Processing Record 25 of Set 5 | tchaourou
# Processing Record 26 of Set 5 | okhotsk
# Processing Record 27 of Set 5 | port antonio
# Processing Record 28 of Set 5 | havre-saint-pierre
# Processing Record 29 of Set 5 | katherine
# Processing Record 30 of Set 5 | jampur
# Processing Record 31 of Set 5 | kristiinankaupunki
# Processing Record 32 of Set 5 | quatre cocos
# Processing Record 33 of Set 5 | airai
# Processing Record 34 of Set 5 | gizo
# Processing Record 35 of Set 5 | sakakah
# Processing Record 36 of Set 5 | avera
# Processing Record 37 of Set 5 | saint george
# Processing Record 38 of Set 5 | carrollton
# Processing Record 39 of Set 5 | tidore
# City not found. Skipping...
# Processing Record 40 of Set 5 | mana
# Processing Record 41 of Set 5 | jambi
# Processing Record 42 of Set 5 | portland
# Processing Record 43 of Set 5 | vestmannaeyjar
# Processing Record 44 of Set 5 | vila franca do campo
# Processing Record 45 of Set 5 | paamiut
# Processing Record 46 of Set 5 | fairbanks
# Processing Record 47 of Set 5 | carnarvon
# Processing Record 48 of Set 5 | pisco
# Processing Record 49 of Set 5 | skuodas
# Processing Record 50 of Set 5 | haukipudas
# Processing Record 1 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 2 of Set 6 | hurfeish
# Processing Record 3 of Set 6 | correntina
# Processing Record 4 of Set 6 | kavieng
# Processing Record 5 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 6 of Set 6 | linqiong
# Processing Record 7 of Set 6 | west bay
# Processing Record 8 of Set 6 | zakinthos
# City not found. Skipping...
# Processing Record 9 of Set 6 | raudeberg
# Processing Record 10 of Set 6 | tsentralnyy
# City not found. Skipping...
# Processing Record 11 of Set 6 | saldanha
# Processing Record 12 of Set 6 | sechura
# Processing Record 13 of Set 6 | fort nelson
# Processing Record 14 of Set 6 | cabedelo
# Processing Record 15 of Set 6 | niedernhausen
# Processing Record 16 of Set 6 | grindavik
# Processing Record 17 of Set 6 | ulaanbaatar
# Processing Record 18 of Set 6 | mahebourg
# Processing Record 19 of Set 6 | zarya
# Processing Record 20 of Set 6 | bac lieu
# Processing Record 21 of Set 6 | geraldton
# Processing Record 22 of Set 6 | ancud
# Processing Record 23 of Set 6 | champerico
# Processing Record 24 of Set 6 | vologda
# Processing Record 25 of Set 6 | homer
# Processing Record 26 of Set 6 | babanusah
# City not found. Skipping...
# Processing Record 27 of Set 6 | moree
# Processing Record 28 of Set 6 | cap malheureux
# Processing Record 29 of Set 6 | port lincoln
# Processing Record 30 of Set 6 | santa rosa
# Processing Record 31 of Set 6 | deputatskiy
# Processing Record 32 of Set 6 | fortuna
# Processing Record 33 of Set 6 | kropotkin
# Processing Record 34 of Set 6 | juneau
# Processing Record 35 of Set 6 | lata
# Processing Record 36 of Set 6 | nemuro
# Processing Record 37 of Set 6 | baker city
# Processing Record 38 of Set 6 | caravelas
# Processing Record 39 of Set 6 | mabai
# Processing Record 40 of Set 6 | rawson
# Processing Record 41 of Set 6 | trenggalek
# Processing Record 42 of Set 6 | katokhi
# City not found. Skipping...
# Processing Record 43 of Set 6 | matara
# Processing Record 44 of Set 6 | nouakchott
# Processing Record 45 of Set 6 | namibe
# Processing Record 46 of Set 6 | motygino
# Processing Record 47 of Set 6 | acajutla
# Processing Record 48 of Set 6 | babu
# Processing Record 49 of Set 6 | dunedin
# Processing Record 50 of Set 6 | hualmay
# Processing Record 1 of Set 7 | kokopo
# Processing Record 2 of Set 7 | juxtlahuaca
# Processing Record 3 of Set 7 | san andres
# Processing Record 4 of Set 7 | kastornoye
# Processing Record 5 of Set 7 | hambantota
# Processing Record 6 of Set 7 | tawkar
# City not found. Skipping...
# Processing Record 7 of Set 7 | van
# Processing Record 8 of Set 7 | kaitangata
# Processing Record 9 of Set 7 | seoul
# Processing Record 10 of Set 7 | hirara
# Processing Record 11 of Set 7 | aksu
# Processing Record 12 of Set 7 | santa vitoria do palmar
# Processing Record 13 of Set 7 | zyryanovsk
# Processing Record 14 of Set 7 | monrovia
# Processing Record 15 of Set 7 | cockburn town
# Processing Record 16 of Set 7 | colomi
# Processing Record 17 of Set 7 | gouyave
# Processing Record 18 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 19 of Set 7 | atambua
# Processing Record 20 of Set 7 | santana
# Processing Record 21 of Set 7 | nouadhibou
# Processing Record 22 of Set 7 | aborlan
# Processing Record 23 of Set 7 | yulara
# Processing Record 24 of Set 7 | narsaq
# Processing Record 25 of Set 7 | abreu e lima
# Processing Record 26 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 7 | nizhniy tsasuchey
# Processing Record 28 of Set 7 | karratha
# Processing Record 29 of Set 7 | hofn
# Processing Record 30 of Set 7 | richards bay
# Processing Record 31 of Set 7 | stantsiya gorchakovo
# City not found. Skipping...
# Processing Record 32 of Set 7 | labuhan
# Processing Record 33 of Set 7 | pervomayskoye
# Processing Record 34 of Set 7 | ketchikan
# Processing Record 35 of Set 7 | rocha
# Processing Record 36 of Set 7 | kyabram
# Processing Record 37 of Set 7 | ijui
# Processing Record 38 of Set 7 | bembereke
# Processing Record 39 of Set 7 | northam
# Processing Record 40 of Set 7 | zhoucheng
# Processing Record 41 of Set 7 | anadyr
# Processing Record 42 of Set 7 | contamana
# Processing Record 43 of Set 7 | ormara
# Processing Record 44 of Set 7 | bambanglipuro
# Processing Record 45 of Set 7 | isangel
# Processing Record 46 of Set 7 | san jeronimo
# Processing Record 47 of Set 7 | manzanillo
# Processing Record 48 of Set 7 | clarksburg
# Processing Record 49 of Set 7 | armenia
# Processing Record 50 of Set 7 | talnakh
# Processing Record 1 of Set 8 | iwanai
# Processing Record 2 of Set 8 | pevek
# Processing Record 3 of Set 8 | alice springs
# Processing Record 4 of Set 8 | rajbiraj
# Processing Record 5 of Set 8 | kavaratti
# Processing Record 6 of Set 8 | belyy yar
# Processing Record 7 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 8 of Set 8 | santa rosalia
# Processing Record 9 of Set 8 | rantepao
# Processing Record 10 of Set 8 | imeni poliny osipenko
# Processing Record 11 of Set 8 | plettenberg bay
# Processing Record 12 of Set 8 | riyadh
# Processing Record 13 of Set 8 | karpathos
# Processing Record 14 of Set 8 | lavrentiya
# Processing Record 15 of Set 8 | mitchell
# Processing Record 16 of Set 8 | herat
# Processing Record 17 of Set 8 | minab
# Processing Record 18 of Set 8 | ulladulla
# Processing Record 19 of Set 8 | carutapera
# Processing Record 20 of Set 8 | ongandjera
# Processing Record 21 of Set 8 | noyabrsk
# Processing Record 22 of Set 8 | bansda
# City not found. Skipping...
# Processing Record 23 of Set 8 | kiruna
# Processing Record 24 of Set 8 | nalut
# Processing Record 25 of Set 8 | derzhavinsk
# Processing Record 26 of Set 8 | itaqui
# Processing Record 27 of Set 8 | gravelbourg
# Processing Record 28 of Set 8 | saint-augustin
# Processing Record 29 of Set 8 | sainte-marie
# Processing Record 30 of Set 8 | haines junction
# Processing Record 31 of Set 8 | yichang
# Processing Record 32 of Set 8 | barahona
# Processing Record 33 of Set 8 | puerto ayora
# Processing Record 34 of Set 8 | hopelchen
# Processing Record 35 of Set 8 | menongue
# Processing Record 36 of Set 8 | winton
# Processing Record 37 of Set 8 | patitirion
# Processing Record 38 of Set 8 | imola
# Processing Record 39 of Set 8 | tuggurt
# City not found. Skipping...
# Processing Record 40 of Set 8 | futtsu
# Processing Record 41 of Set 8 | ballina
# Processing Record 42 of Set 8 | huangchuan
# Processing Record 43 of Set 8 | naryan-mar
# Processing Record 44 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 45 of Set 8 | aksum
# Processing Record 46 of Set 8 | alcantara
# Processing Record 47 of Set 8 | upernavik
# Processing Record 48 of Set 8 | nanakuli
# Processing Record 49 of Set 8 | helena
# Processing Record 50 of Set 8 | ixtapa
# Processing Record 1 of Set 9 | moranbah
# Processing Record 2 of Set 9 | alekseyevsk
# Processing Record 3 of Set 9 | mitsamiouli
# Processing Record 4 of Set 9 | petersberg
# Processing Record 5 of Set 9 | salekhard
# Processing Record 6 of Set 9 | limbang
# Processing Record 7 of Set 9 | sedelnikovo
# City not found. Skipping...
# Processing Record 8 of Set 9 | vikesa
# Processing Record 9 of Set 9 | tekirdag
# Processing Record 10 of Set 9 | vestmanna
# Processing Record 11 of Set 9 | brae
# Processing Record 12 of Set 9 | puerto escondido
# Processing Record 13 of Set 9 | najran
# Processing Record 14 of Set 9 | meadow lake
# Processing Record 15 of Set 9 | wamba
# Processing Record 16 of Set 9 | kontagora
# Processing Record 17 of Set 9 | vao
# Processing Record 18 of Set 9 | alta floresta
# Processing Record 19 of Set 9 | rio gallegos
# Processing Record 20 of Set 9 | noumea
# Processing Record 21 of Set 9 | tornio
# Processing Record 22 of Set 9 | lubbock
# Processing Record 23 of Set 9 | kahului
# Processing Record 24 of Set 9 | porto novo
# Processing Record 25 of Set 9 | samarinda
# Processing Record 26 of Set 9 | arlit
# Processing Record 27 of Set 9 | xuanhua
# Processing Record 28 of Set 9 | arenapolis
# Processing Record 29 of Set 9 | garowe
# Processing Record 30 of Set 9 | eyl
# Processing Record 31 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 32 of Set 9 | pandan
# Processing Record 33 of Set 9 | guhagar
# Processing Record 34 of Set 9 | churapcha
# Processing Record 35 of Set 9 | domoni
# Processing Record 36 of Set 9 | vardo
# Processing Record 37 of Set 9 | laguna
# Processing Record 38 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 39 of Set 9 | mamallapuram
# Processing Record 40 of Set 9 | alghero
# Processing Record 41 of Set 9 | troitskoye
# Processing Record 42 of Set 9 | tual
# Processing Record 43 of Set 9 | san rafael
# Processing Record 44 of Set 9 | kandrian
# Processing Record 45 of Set 9 | luderitz
# Processing Record 46 of Set 9 | kalmunai
# Processing Record 47 of Set 9 | chara
# Processing Record 48 of Set 9 | khormuj
# City not found. Skipping...
# Processing Record 49 of Set 9 | beloha
# Processing Record 50 of Set 9 | maputo
# Processing Record 1 of Set 10 | coquimbo
# Processing Record 2 of Set 10 | vostok
# Processing Record 3 of Set 10 | makuyuni
# Processing Record 4 of Set 10 | tres barras
# Processing Record 5 of Set 10 | awbari
# Processing Record 6 of Set 10 | brignoles
# Processing Record 7 of Set 10 | sebrovo
# Processing Record 8 of Set 10 | dafeng
# Processing Record 9 of Set 10 | kununurra
# Processing Record 10 of Set 10 | arica
# Processing Record 11 of Set 10 | mar del plata
# Processing Record 12 of Set 10 | neftcala
# Processing Record 13 of Set 10 | suntar
# Processing Record 14 of Set 10 | lanzhou
# Processing Record 15 of Set 10 | shache
# Processing Record 16 of Set 10 | port-gentil
# Processing Record 17 of Set 10 | nabire
# Processing Record 18 of Set 10 | tabuk
# Processing Record 19 of Set 10 | foz
# Processing Record 20 of Set 10 | havoysund
# Processing Record 21 of Set 10 | ahipara
# Processing Record 22 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 23 of Set 10 | singaparna
# Processing Record 24 of Set 10 | plouzane
# Processing Record 25 of Set 10 | vredendal
# Processing Record 26 of Set 10 | port hardy
# Processing Record 27 of Set 10 | narrabri
# Processing Record 28 of Set 10 | saquena
# Processing Record 29 of Set 10 | shimoda
# Processing Record 30 of Set 10 | damavand
# Processing Record 31 of Set 10 | solnechnoye
# Processing Record 32 of Set 10 | darhan
# Processing Record 33 of Set 10 | cabo san lucas
# Processing Record 34 of Set 10 | bunia
# Processing Record 35 of Set 10 | kattivakkam
# Processing Record 36 of Set 10 | rio tuba
# Processing Record 37 of Set 10 | xapuri
# Processing Record 38 of Set 10 | novolugovoye
# Processing Record 39 of Set 10 | semey
# Processing Record 40 of Set 10 | darnah
# Processing Record 41 of Set 10 | liyang
# Processing Record 42 of Set 10 | chapais
# Processing Record 43 of Set 10 | parker
# Processing Record 44 of Set 10 | forest
# Processing Record 45 of Set 10 | camalu
# Processing Record 46 of Set 10 | san cristobal
# Processing Record 47 of Set 10 | trzcianka
# Processing Record 48 of Set 10 | salvador
# Processing Record 49 of Set 10 | ponta delgada
# Processing Record 50 of Set 10 | yenagoa
# Processing Record 1 of Set 11 | ozgon
# City not found. Skipping...
# Processing Record 2 of Set 11 | sinnamary
# Processing Record 3 of Set 11 | sisimiut
# Processing Record 4 of Set 11 | egvekinot
# Processing Record 5 of Set 11 | san pedro
# Processing Record 6 of Set 11 | begichevskiy
# Processing Record 7 of Set 11 | macomb
# Processing Record 8 of Set 11 | los llanos de aridane
# Processing Record 9 of Set 11 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 10 of Set 11 | impfondo
# Processing Record 11 of Set 11 | ivnya
# Processing Record 12 of Set 11 | wroclaw
# Processing Record 13 of Set 11 | nome
# Processing Record 14 of Set 11 | port augusta
# Processing Record 15 of Set 11 | smithfield
# Processing Record 16 of Set 11 | cayenne
# Processing Record 17 of Set 11 | batemans bay
# Processing Record 18 of Set 11 | piryion
# City not found. Skipping...
# Processing Record 19 of Set 11 | gangotri
# City not found. Skipping...
# Processing Record 20 of Set 11 | miandoab
# Processing Record 21 of Set 11 | bonavista
# Processing Record 22 of Set 11 | margherita
# Processing Record 23 of Set 11 | bluefield
# Processing Record 24 of Set 11 | sao filipe
# Processing Record 25 of Set 11 | sobolevo
# Processing Record 26 of Set 11 | daru
# Processing Record 27 of Set 11 | goure
# Processing Record 28 of Set 11 | hobyo
# Processing Record 29 of Set 11 | methoni
# Processing Record 30 of Set 11 | pangody
# Processing Record 31 of Set 11 | saint-louis
# Processing Record 32 of Set 11 | muravlenko
# Processing Record 33 of Set 11 | palestine
# Processing Record 34 of Set 11 | conde
# Processing Record 35 of Set 11 | asfi
# Processing Record 36 of Set 11 | tutoia
# Processing Record 37 of Set 11 | udachnyy
# Processing Record 38 of Set 11 | lompoc
# Processing Record 39 of Set 11 | honiara
# Processing Record 40 of Set 11 | nyurba
# Processing Record 41 of Set 11 | araouane
# Processing Record 42 of Set 11 | broome
# Processing Record 43 of Set 11 | acultzingo
# Processing Record 44 of Set 11 | nador
# Processing Record 45 of Set 11 | ilulissat
# Processing Record 46 of Set 11 | killybegs
# Processing Record 47 of Set 11 | maniwaki
# Processing Record 48 of Set 11 | novikovo
# Processing Record 49 of Set 11 | srednekolymsk
# Processing Record 50 of Set 11 | kibre mengist
# Processing Record 1 of Set 12 | sokolo
# Processing Record 2 of Set 12 | lac du bonnet
# Processing Record 3 of Set 12 | kuala terengganu
# Processing Record 4 of Set 12 | kulhudhuffushi
# Processing Record 5 of Set 12 | qiongshan
# Processing Record 6 of Set 12 | taburao
# City not found. Skipping...
# Processing Record 7 of Set 12 | ternate
# Processing Record 8 of Set 12 | gondanglegi
# Processing Record 9 of Set 12 | ekibastuz
# Processing Record 10 of Set 12 | verkhnevilyuysk
# Processing Record 11 of Set 12 | lerwick
# Processing Record 12 of Set 12 | angouleme
# Processing Record 13 of Set 12 | pocone
# Processing Record 14 of Set 12 | port keats
# Processing Record 15 of Set 12 | arawa
# Processing Record 16 of Set 12 | nishihara
# Processing Record 17 of Set 12 | chimbote
# Processing Record 18 of Set 12 | katangli
# Processing Record 19 of Set 12 | qaqortoq
# Processing Record 20 of Set 12 | progreso
# Processing Record 21 of Set 12 | lethem
# Processing Record 22 of Set 12 | manggar
# Processing Record 23 of Set 12 | jurado
# Processing Record 24 of Set 12 | natchez
# Processing Record 25 of Set 12 | vadum
# Processing Record 26 of Set 12 | tura
# Processing Record 27 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 28 of Set 12 | ao luk
# City not found. Skipping...
# Processing Record 29 of Set 12 | kapuskasing
# Processing Record 30 of Set 12 | hanmer springs
# Processing Record 31 of Set 12 | sabha
# Processing Record 32 of Set 12 | mergui
# City not found. Skipping...
# Processing Record 33 of Set 12 | mullaitivu
# City not found. Skipping...
# Processing Record 34 of Set 12 | port blair
# Processing Record 35 of Set 12 | mayumba
# Processing Record 36 of Set 12 | kamenka
# Processing Record 37 of Set 12 | monte alegre
# Processing Record 38 of Set 12 | qena
# Processing Record 39 of Set 12 | xacmaz
# Processing Record 40 of Set 12 | mount gambier
# Processing Record 41 of Set 12 | axim
# Processing Record 42 of Set 12 | calbuco
# Processing Record 43 of Set 12 | tlaxco
# Processing Record 44 of Set 12 | veraval
# Processing Record 45 of Set 12 | fonte boa
# Processing Record 46 of Set 12 | khandyga
# Processing Record 47 of Set 12 | westport
# Processing Record 48 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 49 of Set 12 | parksville
# Processing Record 50 of Set 12 | las vegas
# Processing Record 1 of Set 13 | hasaki
# Processing Record 2 of Set 13 | faya
# Processing Record 3 of Set 13 | balclutha
# Processing Record 4 of Set 13 | kushima
# Processing Record 5 of Set 13 | changji
# Processing Record 6 of Set 13 | flinders
# Processing Record 7 of Set 13 | bam
# Processing Record 8 of Set 13 | bathsheba
# Processing Record 9 of Set 13 | goshogawara
# Processing Record 10 of Set 13 | villarrica
# Processing Record 11 of Set 13 | praia da vitoria
# Processing Record 12 of Set 13 | dianopolis
# City not found. Skipping...
# Processing Record 13 of Set 13 | turukhansk
# Processing Record 14 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 15 of Set 13 | muzhi
# Processing Record 16 of Set 13 | danielskuil
# Processing Record 17 of Set 13 | zhangye
# Processing Record 18 of Set 13 | naze
# Processing Record 19 of Set 13 | tuktoyaktuk
# Processing Record 20 of Set 13 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 21 of Set 13 | kaka
# Processing Record 22 of Set 13 | azrow
# City not found. Skipping...
# Processing Record 23 of Set 13 | inta
# Processing Record 24 of Set 13 | hukuntsi
# Processing Record 25 of Set 13 | soe
# Processing Record 26 of Set 13 | vermillion
# Processing Record 27 of Set 13 | ulaangom
# Processing Record 28 of Set 13 | manicore
# Processing Record 29 of Set 13 | atikokan
# Processing Record 30 of Set 13 | baruun-urt
# Processing Record 31 of Set 13 | krasnaya gora
# Processing Record 32 of Set 13 | samba
# Processing Record 33 of Set 13 | zirandaro
# Processing Record 34 of Set 13 | lebedyan
# Processing Record 35 of Set 13 | jurmala
# Processing Record 36 of Set 13 | formoso do araguaia
# City not found. Skipping...
# Processing Record 37 of Set 13 | guicheng
# City not found. Skipping...
# Processing Record 38 of Set 13 | buala
# Processing Record 39 of Set 13 | kegayli
# City not found. Skipping...
# Processing Record 40 of Set 13 | pimentel
# Processing Record 41 of Set 13 | goderich
# Processing Record 42 of Set 13 | constitucion
# Processing Record 43 of Set 13 | khonsa
# Processing Record 44 of Set 13 | kui buri
# Processing Record 45 of Set 13 | necochea
# Processing Record 46 of Set 13 | carnoustie
# Processing Record 47 of Set 13 | belmonte
# Processing Record 48 of Set 13 | sambava
# Processing Record 49 of Set 13 | nelson bay
# Processing Record 50 of Set 13 | karasburg
# Processing Record 1 of Set 14 | rairangpur
# Processing Record 2 of Set 14 | turayf
# Processing Record 3 of Set 14 | boguchany
# Processing Record 4 of Set 14 | bridgwater
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Aguimes  27.91  -15.45     64.40        63          40       12.75
# 1        Itarema  -2.92  -39.92     77.07        87          21        1.95
# 2         Kodiak  57.79 -152.41     46.40        75          90       12.75
# 3    Clyde River  70.47  -68.59     -4.00        76           1        4.70
# 4        Mombasa  -4.05   39.66     77.20        83          97       11.12
# ..           ...    ...     ...       ...       ...         ...         ...
# 585    Karasburg -28.02   18.75     65.17        25           1        1.77
# 586   Rairangpur  22.27   86.18     82.40        61          15        3.98
# 587       Turayf  31.67   38.66     57.20        54           0        6.93
# 588    Boguchany  58.38   97.45     38.93        60           0        8.77
# 589   Bridgwater  51.13   -3.00     46.00        76          77        1.99
#
#     Country Current Description  Rain inches (last 3 hrs)  \
# 0        ES    scattered clouds                      0.00
# 1        BR          few clouds                      0.00
# 2        US     overcast clouds                      0.00
# 3        CA           clear sky                      0.00
# 4        KE          light rain                      0.94
# ..      ...                 ...                       ...
# 585      NA           clear sky                      0.00
# 586      IN                haze                      0.00
# 587      SA           clear sky                      0.00
# 588      RU           clear sky                      0.00
# 589      GB       broken clouds                      0.00
#
#      Snow inches (last 3 hrs)                 Date
# 0                         0.0  2020-04-20 01:51:22
# 1                         0.0  2020-04-20 01:51:22
# 2                         0.0  2020-04-20 01:51:22
# 3                         0.0  2020-04-20 01:51:23
# 4                         0.0  2020-04-20 01:51:23
# ..                        ...                  ...
# 585                       0.0  2020-04-20 01:53:59
# 586                       0.0  2020-04-20 01:53:59
# 587                       0.0  2020-04-20 01:53:59
# 588                       0.0  2020-04-20 01:53:59
# 589                       0.0  2020-04-20 01:54:00
#
# [590 rows x 12 columns]

# %%
columns = ['City', 'Country', 'Date', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
       'Wind Speed',  'Current Description',
       'Rain inches (last 3 hrs)', 'Snow inches (last 3 hrs)']

city_data_df = city_data_df.reindex(columns = columns)
city_data_df
# Out:
#             City Country                 Date    Lat     Lng  Max Temp  \
# 0        Aguimes      ES  2020-04-20 01:51:22  27.91  -15.45     64.40
# 1        Itarema      BR  2020-04-20 01:51:22  -2.92  -39.92     77.07
# 2         Kodiak      US  2020-04-20 01:51:22  57.79 -152.41     46.40
# 3    Clyde River      CA  2020-04-20 01:51:23  70.47  -68.59     -4.00
# 4        Mombasa      KE  2020-04-20 01:51:23  -4.05   39.66     77.20
# ..           ...     ...                  ...    ...     ...       ...
# 585    Karasburg      NA  2020-04-20 01:53:59 -28.02   18.75     65.17
# 586   Rairangpur      IN  2020-04-20 01:53:59  22.27   86.18     82.40
# 587       Turayf      SA  2020-04-20 01:53:59  31.67   38.66     57.20
# 588    Boguchany      RU  2020-04-20 01:53:59  58.38   97.45     38.93
# 589   Bridgwater      GB  2020-04-20 01:54:00  51.13   -3.00     46.00
#
#      Humidity  Cloudiness  Wind Speed Current Description  \
# 0          63          40       12.75    scattered clouds
# 1          87          21        1.95          few clouds
# 2          75          90       12.75     overcast clouds
# 3          76           1        4.70           clear sky
# 4          83          97       11.12          light rain
# ..        ...         ...         ...                 ...
# 585        25           1        1.77           clear sky
# 586        61          15        3.98                haze
# 587        54           0        6.93           clear sky
# 588        60           0        8.77           clear sky
# 589        76          77        1.99       broken clouds
#
#      Rain inches (last 3 hrs)  Snow inches (last 3 hrs)
# 0                        0.00                       0.0
# 1                        0.00                       0.0
# 2                        0.00                       0.0
# 3                        0.00                       0.0
# 4                        0.94                       0.0
# ..                        ...                       ...
# 585                      0.00                       0.0
# 586                      0.00                       0.0
# 587                      0.00                       0.0
# 588                      0.00                       0.0
# 589                      0.00                       0.0
#
# [590 rows x 12 columns]

# %%
city_data_df.to_csv("WeatherPy_challenge.csv")

# %%
city_data_df.to_csv("WeatherPy_vacation.csv")
