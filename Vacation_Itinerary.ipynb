# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
# Import the dependencies.
import gmaps
import requests
# Import the API key.
from config import g_key

# %%
#import WeatherPy_vacation.csv file from part 1 as new DF
hotels_df = pd.read_csv("WeatherPy_vacation.csv")
hotels_df.tail(30)
# Out:
#     Unnamed: 0              City Country  Max Temp Current Description    Lat  \
# 17         203      Quatre Cocos      MU     77.00       broken clouds -20.21
# 18         217         Carnarvon      AU     75.20       broken clouds -24.87
# 19         234         Mahebourg      MU     77.00       broken clouds -20.41
# 20         243    Cap Malheureux      MU     77.00       broken clouds -19.98
# 21         262              Babu      CN     76.14     overcast clouds  24.42
# 22         277          Monrovia      LR     78.80    scattered clouds   6.30
# 23         278     Cockburn Town      TC     79.21    scattered clouds  21.46
# 24         298         Bembereke      BJ     76.57     overcast clouds  10.23
# 25         303            Ormara      PK     79.81    scattered clouds  25.21
# 26         326             Minab      IR     75.20                mist  27.15
# 27         328        Carutapera      BR     79.12    scattered clouds  -1.20
# ...

# %%
hotels_df.dtypes
# Out:
# Unnamed: 0               int64
# City                    object
# Country                 object
# Max Temp               float64
# Current Description     object
# Lat                    float64
# Lng                    float64
# Hotel Name              object
# dtype: object

# %%
#Get Hotels in the Americas
#las_vegas = hotels_df.loc[(hotels_df["Country"] == "US") & (hotels_df["City"] == "Las Vegas")]
#lubbock = hotels_df.loc[(hotels_df["Country"] == "US") & (hotels_df["City"] == "Lubbock")]
#jurado = hotels_df.loc[(hotels_df["Country"] == "CO") & (hotels_df["City"] == "Jurado")]
#san_patricio = hotels_df.loc[(hotels_df["Country"] == "MX") & (hotels_df["City"] == "San Patricio")]
#hotels_df_two
#print(las_vegas)
#print(lubbock)
#print(jurado)
#print(san_patricio)

# %%
las_vegas = hotels_df.loc[(hotels_df["Country"] == "US") & (hotels_df["City"] == "Las Vegas")]
las_vegas
# Out:
#     Unnamed: 0       City Country  Max Temp Current Description    Lat  \
# 43         542  Las Vegas      US      78.8           clear sky  36.17
#
#        Lng            Hotel Name
# 43 -115.14  Plaza Hotel & Casino

# %%
lubbock = hotels_df.loc[(hotels_df["Country"] == "US") & (hotels_df["City"] == "Lubbock")]
lubbock
# Out:
#     Unnamed: 0     City Country  Max Temp Current Description   Lat     Lng  \
# 34         377  Lubbock      US      75.2          few clouds  33.6 -101.83
#
#                                            Hotel Name
# 34  La Quinta Inn by Wyndham Lubbock - Downtown Ci...

# %%
puerto_escondido = hotels_df.loc[(hotels_df["Country"] == "MX") & (hotels_df["City"] == "Puerto Escondido")]
puerto_escondido
# Out:
#     Unnamed: 0              City Country  Max Temp Current Description    Lat  \
# 32         367  Puerto Escondido      MX     78.98          few clouds  15.85
#
#       Lng                     Hotel Name
# 32 -97.07  Aldea del Bazar Hotel and Spa

# %%
san_patricio = hotels_df.loc[(hotels_df["Country"] == "MX") & (hotels_df["City"] == "San Patricio")]
san_patricio
# Out:
#    Unnamed: 0          City Country  Max Temp Current Description    Lat  \
# 3          21  San Patricio      MX      75.2           clear sky  19.22
#
#      Lng         Hotel Name
# 3 -104.7  Hotel Cabo Blanco

# %%
City_No = [21,367,377,542]
City = ["San Patricio", "Puerto Escondido", "Lubbock", "Las Vegas"]
Country = ["MX", "MX", "US", "US"]
Max_Temp = [75.2, 78.98, 75.2, 78.8]
Current_Description = ["clear sky", "few clouds", "few clouds", "clear sky"]
Lat = [19.22, 15.85, 33.6, 36.17]
Lng = [-104.7, -97.07, -101.83, -115.14]
Hotel_Name = ["Hotel Cabo Blanco", "Aldea del Bazar Hotel and Spa","La Quinta Inn by Wyndham Lubbock - Downtown Civic Center", "Plaza Hotel & Casino"]
four_cities_df = pd.DataFrame({"City No": City_No, "City": City, "Country": Country, "Max Temp": Max_Temp, "Current Description" : Current_Description, "Lat" : Lat, "Lng": Lng, "Hotel Name": Hotel_Name})
four_cities_df
# Out:
#    City No              City Country  Max Temp Current Description    Lat  \
# 0       21      San Patricio      MX     75.20           clear sky  19.22
# 1      367  Puerto Escondido      MX     78.98          few clouds  15.85
# 2      377           Lubbock      US     75.20          few clouds  33.60
# 3      542         Las Vegas      US     78.80           clear sky  36.17
#
#       Lng                                         Hotel Name
# 0 -104.70                                  Hotel Cabo Blanco
# 1  -97.07                      Aldea del Bazar Hotel and Spa
# 2 -101.83  La Quinta Inn by Wyndham Lubbock - Downtown Ci...
# 3 -115.14                               Plaza Hotel & Casino

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# %%
# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in four_cities.iterrows()]

# %%
# Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
locations = four_cities_df[["Lat", "Lng"]]
max_temp = four_cities_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
locations = four_cities_df[["Lat", "Lng"]]
max_temp = four_cities_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
